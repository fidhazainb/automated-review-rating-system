# %% [markdown]
# #cleaning new dataset

# %%
import pandas as pd
import re
import nltk

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
df = pd.read_csv("data/real data collected/New folder/Reviews.csv")

# %%
df.head()
# Out:
#    overall                                        review text
# 0        5  I have bought several of the Vitality canned d...
# 1        1  Product arrived labeled as Jumbo Salted Peanut...
# 2        4  This is a confection that has been around a fe...
# 3        2  If you are looking for the secret ingredient i...
# 4        5  Great taffy at a great price.  There was a wid...

# %%
df = df.drop_duplicates(subset=["review text"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 393578 entries, 0 to 568453
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   overall      393578 non-null  int64
#  1   review text  393578 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 9.0+ MB

# %%
print(df['overall'].value_counts())
# Out:
# overall
# 5    250715
# 4     56042
# 1     36275
# 3     29754
# 2     20792
# Name: count, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# overall        0
# review text    0
# dtype: int64

# %%
def clean_text(text):
    text = str(text).lower()                                # lowercase
    text = re.sub(r"http\S+|www\S+", "", text)              # remove links
    text = re.sub(r"<.*?>", "", text)                       # remove HTML
    text = re.sub(r"[^a-z\s]", " ", text)                   # keep only letters
    text = re.sub(r"\s+", " ", text).strip()                # remove extra spaces
    return text

# %%
def process_text(text):
    words = text.split()
    words = [w for w in words if w not in stop_words]       # remove stopwords
    words = [lemmatizer.lemmatize(w) for w in words]        # lemmatize
    return " ".join(words)

# %%
df["cleaned_reviews"] = df["review text"].apply(clean_text).apply(process_text)

# %%
df.head()
# Out:
#    overall                                        review text  \
# 0        5  I have bought several of the Vitality canned d...
# 1        1  Product arrived labeled as Jumbo Salted Peanut...
# 2        4  This is a confection that has been around a fe...
# 3        2  If you are looking for the secret ingredient i...
# 4        5  Great taffy at a great price.  There was a wid...
#
#                                      cleaned_reviews
# 0  bought several vitality canned dog food produc...
# 1  product arrived labeled jumbo salted peanut pe...
# 2  confection around century light pillowy citrus...
# 3  looking secret ingredient robitussin believe f...
# 4  great taffy great price wide assortment yummy ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 393578 entries, 0 to 568453
# Data columns (total 3 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   overall          393578 non-null  int64
#  1   review text      393578 non-null  object
#  2   cleaned_reviews  393578 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 12.0+ MB

# %%
df["review_length"] = df["cleaned_reviews"].str.split().apply(len)

# %%
df = df.reset_index(drop=True)

# %%
df = df[(df['review_length']>=3)&(df['review_length']<=200)]

# %%
df.head()
# Out:
#    overall                                        review text  \
# 0        5  I have bought several of the Vitality canned d...
# 1        1  Product arrived labeled as Jumbo Salted Peanut...
# 2        4  This is a confection that has been around a fe...
# 3        2  If you are looking for the secret ingredient i...
# 4        5  Great taffy at a great price.  There was a wid...
#
#                                      cleaned_reviews  review_length
# 0  bought several vitality canned dog food produc...             23
# 1  product arrived labeled jumbo salted peanut pe...             18
# 2  confection around century light pillowy citrus...             40
# 3  looking secret ingredient robitussin believe f...             18
# 4  great taffy great price wide assortment yummy ...             13

# %%
df.tail()
# Out:
#         overall                                        review text  \
# 393573        5  Great for sesame chicken..this is a good if no...
# 393574        2  I'm disappointed with the flavor. The chocolat...
# 393575        5  These stars are small, so you can give 10-15 o...
# 393576        5  These are the BEST treats for training and rew...
# 393577        5  I am very satisfied ,product is as advertised,...
#
#                                           cleaned_reviews  review_length
# 393573  great sesame chicken good better resturants ea...             12
# 393574  disappointed flavor chocolate note especially ...             22
# 393575  star small give one training session tried tra...             37
# 393576  best treat training rewarding dog good groomin...             18
# 393577  satisfied product advertised use cereal raw vi...              9

# %%
df = df.drop(columns=['review text'])

# %%
df.tail()
# Out:
#         overall                                    cleaned_reviews  \
# 393573        5  great sesame chicken good better resturants ea...
# 393574        2  disappointed flavor chocolate note especially ...
# 393575        5  star small give one training session tried tra...
# 393576        5  best treat training rewarding dog good groomin...
# 393577        5  satisfied product advertised use cereal raw vi...
#
#         review_length
# 393573             12
# 393574             22
# 393575             37
# 393576             18
# 393577              9

# %%
max_count = 2000  

# Downsample df2 to at most 2000 per rating
df_balanced = (
    df.groupby("overall", group_keys=False)
       .apply(lambda x: x.sample(n=min(len(x), max_count), random_state=42))
       .reset_index(drop=True)
)

print(df_balanced['overall'].value_counts())
# Out:
# overall
# 1    2000
# 2    2000
# 3    2000
# 4    2000
# 5    2000
# Name: count, dtype: int64
# C:\Users\hp\AppData\Local\Temp\ipykernel_10912\3555755308.py:6: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(n=min(len(x), max_count), random_state=42))

# %%
df_balanced.to_csv("data/cleaned_dataset/last_data.csv", index=False)

# %%
df_balanced.head()
# Out:
#    overall                                    cleaned_reviews  review_length
# 0        1  taste much like cherry flavored cough syrup dr...             16
# 1        1  note purchased box july may amazon must used d...            171
# 2        1  first little disappointed got one pouch try ta...             41
# 3        1  needed filler item figured get food sure use w...             46
# 4        1  highly recommended hei customer like fragmenta...             14

# %%
df_balanced.tail()
# Out:
#       overall                                    cleaned_reviews  \
# 9995        5  using nupro year pleased result nupro balanced...
# 9996        5   good quality dog eat many dry dog food turn nose
# 9997        5  fed trio min american eskimo french bulldog bl...
# 9998        5  complaint purchase delicious nut shell half wa...
# 9999        5  store manager always interested customer would...
#
#       review_length
# 9995             34
# 9996             10
# 9997             43
# 9998             24
# 9999             71
