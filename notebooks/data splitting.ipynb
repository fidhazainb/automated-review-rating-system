# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\hp\Desktop\automatedreviewratingsystem

# %%
print(os.listdir('.'))
# Out:
# ['.git', '.ipynb_checkpoints', 'advanced data preprocessing of balanced data.ipynb', 'app.py', 'crosstesting.ipynb', 'data', 'imbalanced data preprocessing and visualization.ipynb', 'models', 'newimbalanced.ipynb', 'practice.ipynb', 'README.md', 'Untitled.ipynb', 'venv']

# %%
import os

print("Current directory:", os.getcwd())
print("Contents in current directory:", os.listdir('.'))
print("Contents in 'data':", os.listdir('data'))
# Out:
# Current directory: C:\Users\hp\Desktop\automatedreviewratingsystem
# Contents in current directory: ['.git', '.ipynb_checkpoints', 'advanced data preprocessing of balanced data.ipynb', 'app.py', 'crosstesting.ipynb', 'data', 'imbalanced data preprocessing and visualization.ipynb', 'models', 'newimbalanced.ipynb', 'practice.ipynb', 'README.md', 'Untitled.ipynb', 'venv']
# Contents in 'data': ['.ipynb_checkpoints', 'balanced.ipynb', 'cleaned_dataset', 'real data collected']

# %%
print(os.listdir('data/cleaned_dataset'))
# Out:
# ['balanced_df.csv', 'cleaned_balanced_dataset.csv', 'cleaned_orginal data.csv', 'imbalanced_dataset.csv', 'New folder']

# %%
import pandas as pd

file_path = 'data/cleaned_dataset/cleaned_orginal data.csv'
df = pd.read_csv(file_path)

print(df.shape)
print(df.head())
# Out:
# (30929, 3)
#                                          review text  overall  review_length
# 0                                         No issues.        4              2
# 1  Purchased this for my device, it worked as adv...        5             31
# 2  it works as expected. I should have sprung for...        4             31
# 3  This think has worked out great.Had a diff. br...        5             66
# 4  Bought it with Retail Packaging, arrived legit...        5             52

# %%
print(df['overall'].value_counts())
# Out:
# overall
# 5    15569
# 4     7107
# 1     3265
# 3     2763
# 2     2225
# Name: count, dtype: int64

# %%
target_col = 'overall'

# %%
balanced_size_per_class = 2000
balanced_samples = []

for cls in sorted(df[target_col].unique()):
    cls_rows = df[df[target_col] == cls]
    sampled = cls_rows.sample(n=balanced_size_per_class, random_state=42)
    balanced_samples.append(sampled)

balanced_df = pd.concat(balanced_samples).reset_index(drop=True)

# %%
balanced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   review text    10000 non-null  object
#  1   overall        10000 non-null  int64
#  2   review_length  10000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 234.5+ KB

# %%
leftover_df = df.drop(balanced_df.index).reset_index(drop=True)
imbalanced_df = leftover_df.copy()

# %%
imbalanced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20929 entries, 0 to 20928
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   review text    20929 non-null  object
#  1   overall        20929 non-null  int64
#  2   review_length  20929 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 490.7+ KB

# %%
# balanced_df.to_csv('data/balanced_dataset.csv', index=False)
imbalanced_df.to_csv('data/imbalanced_dataset.csv', index=False)

print("Balanced dataset shape:", balanced_df.shape)
print("Imbalanced dataset shape:", imbalanced_df.shape)
# Out:
# Balanced dataset shape: (10000, 3)
# Imbalanced dataset shape: (20929, 3)
